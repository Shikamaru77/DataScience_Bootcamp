# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df = pd.DataFrame(iris['data'], columns = iris['feature_names'])
df['species'] = [iris.target_names[n] for n in iris.target]
df
#here, iris.target = 0, 1 & 2 and target_names are just setosa, etc
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
df_setosa = df.loc[df['species']== 'setosa']
df_virginica = df.loc[df['species']== 'virginica']
df_versicolor = df.loc[df['species']== 'versicolor']
df_setosa.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
iris['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# performin univariate analysis by taking sepal_length as a feature to analyse for target
import matplotlib.pyplot as plt
plt.scatter(df_setosa['sepal length (cm)'], [0] * len(df_setosa), label='Setosa', marker='o')
plt.scatter(df_virginica['sepal length (cm)'], [1] * len(df_virginica), label='Virginica', marker='o')
plt.scatter(df_versicolor['sepal length (cm)'], [2] * len(df_versicolor), label='Versicolor', marker='o')

plt.xlabel('Sepal Length (cm)')
plt.yticks([0, 1, 2], ['Setosa', 'Virginica', 'Versicolor'])
plt.legend()
plt.show()

# %% [markdown]
# ## Bivariate

# %%
#performing bi variate
sns.FacetGrid(df, hue = 'species', height = 5).map(plt.scatter, 'sepal length (cm)', 'sepal width (cm)').add_legend();
plt.show()

# %% [markdown]
# ## Multivariate

# %%
sns.pairplot(df, hue = 'species', height = 5)
